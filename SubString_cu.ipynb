# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayon150/Parallel_Processing/blob/main/SubString_cu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile search_phonebook.cu
# Out:
# Writing search_phonebook.cu

# %%
# !nvcc -arch=sm_75 search_phonebook.cu -o search_phonebook

# %%
# !./search_phonebook SADIA 256
# Out:
# GPU Search Complete. Threads used per block: 256
# Total Matches Found: 41 (Threshold: 3)
